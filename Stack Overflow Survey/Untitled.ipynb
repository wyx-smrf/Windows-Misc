# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
dtypes_graph_params = {'data': df, 
                       'title': 'Data Types', 
                       'title_location': 'center'}

def dtypes_graph(data, title, title_location):
    dtype_count  = data.dtypes.value_counts()
    dtype_name_list = dtype_count.index.tolist()
    
    plt.pie(dtype_count, labels=dtype_name_list, autopct='%.1f%%')
    plt.title(title, loc=title_location)
    
    return plt.show()

dtypes_graph(**dtypes_graph_params)

# %%
new_data = df['Employment']

# %%
new_data.iloc[:4]
# Out:
# 0                    NaN
# 1    Employed, full-time
# 2    Employed, full-time
# 3    Employed, full-time
# Name: Employment, dtype: object

# %%
def view_data(data, number):
    
    # From start to the specified number (integer location)
    lookup = data.iloc[:number]
    return lookup

bob = view_data(new_data, 4)

# %%
bob
# Out:
# 0                    NaN
# 1    Employed, full-time
# 2    Employed, full-time
# 3    Employed, full-time
# Name: Employment, dtype: object
